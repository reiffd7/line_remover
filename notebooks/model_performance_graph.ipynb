# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
plt.style.use('ggplot')

# %%
data = pd.read_csv('../models/model_history/First.csv')

# %%
data1 = pd.read_csv('../models/model_history/First.txt', sep=",", header=None)

# %%
data
# Out:
#      recall  val_recall  val_precision  val_loss      loss  accuracy  \
# 0  0.835165         0.0            0.0  0.160283  0.562700  0.751381
# 1  0.950980         0.0            0.0  0.530838  0.323071  0.883978
# 2  0.965909         0.0            0.0  0.219252  0.242541  0.933702
# 3  0.989362         0.0            0.0  0.164152  0.151717  0.961326
# 4  0.950000         0.0            0.0  0.409006  0.193697  0.950276
#
#    val_accuracy  precision
# 0      0.956522   0.716981
# 1      0.652174   0.858407
# 2      0.913043   0.904255
# 3      0.913043   0.939394
# 4      0.913043   0.938272

# %%
fig, ax = plt.subplots(1, 1)
ax.plot(data['val_loss'], label = 'Test Loss')
ax.plot(data['loss'], label = 'Training Loss')
ax.set_xlabel('Epoch')
ax.set_ylabel('Loss')
ax.set_title('Model Loss')
ax.legend()

# %%
fig, ax = plt.subplots(1, 1)
ax.plot(data['val_accuracy'], label = 'Test Loss')
ax.plot(data['accuracy'], label = 'Training Loss')
ax.set_xlabel('Epoch')
ax.set_ylabel('Accuracy')
ax.set_title('Model Accuracy')
ax.legend()

# %%
fig, ax = plt.subplots(1, 1)
ax.plot(data['val_precision'], label = 'Test Precision')
ax.plot(data['precision'], label = 'Training Precision')
ax.plot(data['val_recall'], label = 'Test Recall')
ax.plot(data['recall'], label = 'Training Recall')
ax.set_xlabel('Epoch')
ax.set_ylabel('Rate')
ax.set_title('Model Precision & Recall')
ax.legend()
